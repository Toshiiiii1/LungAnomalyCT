# %%
# !wget https://zenodo.org/records/3723295/files/subset3.zip
# Out:
# --2024-11-03 08:54:23--  https://zenodo.org/records/3723295/files/subset3.zip
# Resolving zenodo.org (zenodo.org)... 188.184.103.159, 188.184.98.238, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.103.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6896620114 (6.4G) [application/octet-stream]
# Saving to: 'subset3.zip'
#
# subset3.zip         100%[===================>]   6.42G  5.50MB/s    in 13m 1s
#
# 2024-11-03 09:07:25 (8.42 MB/s) - 'subset3.zip' saved [6896620114/6896620114]

# %%
# !wget https://zenodo.org/records/3723295/files/annotations.csv
# Out:
# --2024-11-03 09:07:26--  https://zenodo.org/records/3723295/files/annotations.csv
# Resolving zenodo.org (zenodo.org)... 188.184.98.238, 188.184.103.159, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136986 (134K) [text/plain]
# Saving to: 'annotations.csv'
#
# annotations.csv     100%[===================>] 133.78K   200KB/s    in 0.7s
#
# 2024-11-03 09:07:27 (200 KB/s) - 'annotations.csv' saved [136986/136986]

# %%
# !unzip -q /kaggle/working/subset3.zip -d /kaggle/working/

# %%
# !rm subset3.zip

# %%
import SimpleITK as sitk
import numpy as np
import csv
from glob import glob
import pandas as pd
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import cv2

# %%
# LUNA_mask_extraction.py
subset = "subset3"
file_list = os.listdir(f"/kaggle/working//{subset}")
file_list = list(map(lambda file : f"/kaggle/working/{subset}/" + file, file_list))

# %%
def myFunc(file):
  if file.endswith(".mhd"):
    return True
  else:
    return False

file_list = list(filter(myFunc, file_list))

# %%
# !mkdir ct_images

# %%
def make_mask(center, diam, z, width, height, spacing, origin):
    '''
        Center : centers of circles px -- list of coordinates x,y,z
        diam : diameters of circles px -- diameter
        widthXheight : pixel dim of image
        spacing = mm/px conversion rate np array x,y,z
        origin = x,y,z mm np.array
        z = z position of slice in world coordinates mm
    '''
    mask = np.zeros([height, width]) # 0's everywhere except nodule swapping x,y to match img
    #convert to nodule space from world coordinates

    # Defining the voxel range in which the nodule falls
    v_center = (center - origin)/spacing
    v_diam = int(diam/spacing[0] + 1)
    v_xmin = np.max([0, int(v_center[0]-v_diam/2) - 2])
    v_xmax = np.min([width-1, int(v_center[0]+v_diam/2) + 2])
    v_ymin = np.max([0, int(v_center[1]-v_diam/2) - 2]) 
    v_ymax = np.min([height-1, int(v_center[1]+v_diam/2) + 2])

    v_xrange = range(v_xmin, v_xmax+1)
    v_yrange = range(v_ymin, v_ymax+1)

    # Fill in 1 within sphere around nodule
    for v_x in v_xrange:
        for v_y in v_yrange:
            p_x = spacing[0]*v_x + origin[0]
            p_y = spacing[1]*v_y + origin[1]
            if np.linalg.norm(center - np.array([p_x, p_y, z])) <= diam:
                mask[int((p_y-origin[1]) / spacing[1]), int((p_x-origin[0]) / spacing[0])] = 1.0
    return(mask, [v_xmin, v_xmax, v_ymin, v_ymax])

def get_filename(case):
    global file_list
    for f in file_list:
        if case in f:
            return(f)
        
def normalize(image):
    MIN_BOUND = -1000.0
    MAX_BOUND = 400.0
    image = (image - MIN_BOUND) / (MAX_BOUND - MIN_BOUND)
    image[image>1] = 1.
    image[image<0] = 0.
    return image

# %%
if __name__ == "__main__":
    df_node = pd.read_csv("/kaggle/working/annotations.csv")
    df_node["file"] = df_node["seriesuid"].apply(get_filename)
    df_node = df_node.dropna()
    # Define the file name
    file_name = 'output.csv'

    # Define the column names
    columns = ['x_min', 'x_max', 'y_min', 'y_max', 'ID']

    # Create an empty CSV file with column headers
    with open(file_name, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=columns)
        writer.writeheader()
    df_roi = pd.read_csv("output.csv")
    df_roi_cur = dict()
    
    print(f"TRÍCH XUẤT ẢNH VÀ TỌA ĐỘ TỪ FILE .raw VÀ FILE .mhd TỪ {subset}")
    for fcount, img_file in enumerate(tqdm(file_list)):
        mini_df = df_node[df_node["file"]==img_file] # get all nodules associate with file
        if len(mini_df) > 0:       # some files may not have a nodule--skipping those
            itk_img = sitk.ReadImage(img_file) # read .mhd file
            img_array = sitk.GetArrayFromImage(itk_img) # indexes are z,y,x (notice the ordering)
            num_z, height, width = img_array.shape
            origin = np.array(itk_img.GetOrigin())      # x,y,z  Origin in world coordinates (mm)
            spacing = np.array(itk_img.GetSpacing())    # spacing of voxels in world coor. (mm)
            
            for node_idx, cur_row in mini_df.iterrows():       
                node_x = cur_row["coordX"]
                node_y = cur_row["coordY"]
                node_z = cur_row["coordZ"]
                diam = cur_row["diameter_mm"]
                
                # imgs = np.ndarray([num_z, height, width], dtype=np.float16)
                center = np.array([node_x, node_y, node_z])   # nodule center
                v_center = np.rint((center-origin)/spacing)  # nodule center in voxel space (still x,y,z ordering)
            
                for i_z in range(0, num_z): # clip prevents going out of bounds in Z
                    _, roi = make_mask(center, diam, i_z*spacing[2]+origin[2], width, height, spacing, origin)
                    if i_z == v_center[2]:
                        roi_key = f"{img_file.split('/')[-1].rsplit('.', 1)[0]}_{i_z}_{node_idx}"
                        img_name = f"{img_file.split('/')[-1].rsplit('.', 1)[0]}_{i_z}_{node_idx}.png"
                        img = normalize(img_array[i_z])
                        img = img * 255
                        img_rgb = np.stack((img,)*3, -1)
                        cv2.imwrite(f"/kaggle/working/ct_images/{img_name}", img_rgb)
                        df_roi_cur.update({roi_key: roi})
                    # imgs[i_z] = img_array[i_z]
    df_temp = pd.DataFrame.from_dict(df_roi_cur, columns=["x_min", "x_max", "y_min", "y_max"], orient='index')
    df_temp["ID"] = list(df_roi_cur.keys())
    df_temp = df_temp.reset_index(drop=True)
    df_roi = pd.concat([df_roi, df_temp])
    df_roi.to_csv("output.csv", index=False)
# Out:
# TRÍCH XUẤT ẢNH VÀ TỌA ĐỘ TỪ FILE .raw VÀ FILE .mhd TỪ subset3
# 100%|██████████| 89/89 [02:18<00:00,  1.56s/it]

# %%
# !zip -r subset3.zip /kaggle/working/ct_images /kaggle/working/output.csv
# Out:
#   adding: kaggle/working/ct_images/ (stored 0%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.324567010179873305471925391582_105_906.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.324290109423920971676288828329_215_904.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.199670099218798685977406484591_90_398.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.300246184547502297539521283806_108_826.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.254254303842550572473665729969_99_640.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.197063290812663596858124411210_113_385.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.313283554967554803238484128406_98_868.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.225227615446398900698431118292_259_523.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.244681063194071446501270815660_129_596.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.272190966764020277652079081128_67_709.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.324567010179873305471925391582_214_905.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.204303454658845815034433453512_300_424.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.106164978370116976238911317774_63_11.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.244447966386688625240438849169_210_594.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689_76_179.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202464973819273687476049035824_170_418.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689_89_174.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.269075535958871753309238331179_99_696.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.603166427542096384265514998412_242_1040.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689_98_178.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.208511362832825683639135205368_352_442.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.100953483028192176989979435275_76_7.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_208_413.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_69_412.png (deflated 12%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.194488534645348916700259325236_299_369.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.204303454658845815034433453512_298_425.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.274052674198758621258447180130_158_715.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.277662902666135640561346462196_315_735.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.162845309248822193437735868939_501_226.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.313283554967554803238484128406_83_869.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.191266041369462391833537519639_197_357.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.850739282072340578344345230132_166_1120.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.300246184547502297539521283806_50_825.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.179730018513720561213088132029_77_312.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_101_411.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.126631670596873065041988320084_84_99.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.171667800241622018839592854574_79_263.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.237428977311365557972720635401_115_566.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.121391737347333465796214915391_155_71.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.225227615446398900698431118292_118_520.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.127965161564033605177803085629_111_102.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.204303454658845815034433453512_209_423.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.276556509002726404418399209377_96_730.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.199670099218798685977406484591_87_397.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.194488534645348916700259325236_125_368.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.154703816225841204080664115280_108_201.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689_144_177.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.192419869605596446455526220766_134_363.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.323541312620128092852212458228_76_894.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689_169_175.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.367204840301639918160517361062_88_960.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.154703816225841204080664115280_113_202.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.278010349511857248000260557753_239_736.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.149463915556499304732434215056_75_181.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.275007193025729362844652516689_73_719.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_201_409.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.822128649427327893802314908658_47_1107.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.154703816225841204080664115280_103_200.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.197063290812663596858124411210_34_384.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.148447286464082095534651426689_158_176.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.324290109423920971676288828329_185_901.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.225227615446398900698431118292_174_522.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.324290109423920971676288828329_201_902.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.293593766328917170359373773080_306_782.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.126631670596873065041988320084_229_100.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.292057261351416339496913597985_137_779.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.197063290812663596858124411210_93_386.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.172573195301625265149778785969_296_266.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.172573195301625265149778785969_190_267.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.324290109423920971676288828329_210_903.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.404768898286087278137462774930_82_972.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.275007193025729362844652516689_78_718.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.252697338970999211181671881792_123_634.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.225227615446398900698431118292_120_521.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.292057261351416339496913597985_89_776.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.123697637451437522065941162930_172_85.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.292057261351416339496913597985_96_777.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.975426625618184773401026809852_122_1179.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.208511362832825683639135205368_342_443.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156_43_999.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.219349715895470349269596532320_101_494.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.324567010179873305471925391582_266_907.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.274052674198758621258447180130_108_716.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.614147706162329660656328811671_69_1043.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.244204120220889433826451158706_139_592.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.961063442349005937536597225349_378_1171.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156_31_998.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_69_408.png (deflated 12%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_122_406.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.254254303842550572473665729969_149_641.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.321465552859463184018938648244_113_886.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.177785764461425908755977367558_216_303.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.204303454658845815034433453512_494_427.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.197063290812663596858124411210_76_387.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.269075535958871753309238331179_94_695.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_137_405.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.319066480138812986026181758474_97_883.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.197063290812663596858124411210_65_383.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.625270601160880745954773142570_170_1051.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.135657246677982059395844827629_120_133.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.319066480138812986026181758474_118_884.png (deflated 12%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.970428941353693253759289796610_104_1177.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.339142594937666268384335506819_82_954.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.313283554967554803238484128406_34_870.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.167919147233131417984739058859_247_235.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.276556509002726404418399209377_83_729.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.842317928015463083368074520378_146_1119.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.272190966764020277652079081128_106_710.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_67_407.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.487745546557477250336016826588_118_1004.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.204303454658845815034433453512_505_426.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.177685820605315926524514718990_201_302.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202187810895588720702176009630_81_410.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.275007193025729362844652516689_66_717.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.970428941353693253759289796610_108_1178.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.244204120220889433826451158706_142_591.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.336225579776978874775723463327_41_940.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.292057261351416339496913597985_106_778.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.269075535958871753309238331179_96_694.png (deflated 20%)
#   adding: kaggle/working/output.csv (deflated 73%)
