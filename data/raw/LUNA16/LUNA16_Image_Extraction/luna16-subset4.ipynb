# %%
# !wget https://zenodo.org/records/3723295/files/annotations.csv
# Out:
# --2024-11-03 09:33:02--  https://zenodo.org/records/3723295/files/annotations.csv
# Resolving zenodo.org (zenodo.org)... 188.184.98.238, 188.184.103.159, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136986 (134K) [text/plain]
# Saving to: 'annotations.csv'
#
# annotations.csv     100%[===================>] 133.78K   204KB/s    in 0.7s
#
# 2024-11-03 09:33:04 (204 KB/s) - 'annotations.csv' saved [136986/136986]

# %%
# !wget https://zenodo.org/records/3723295/files/subset4.zip
# Out:
# --2024-11-03 09:33:05--  https://zenodo.org/records/3723295/files/subset4.zip
# Resolving zenodo.org (zenodo.org)... 188.184.103.159, 188.185.79.172, 188.184.98.238, ...
# Connecting to zenodo.org (zenodo.org)|188.184.103.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6856144330 (6.4G) [application/octet-stream]
# Saving to: 'subset4.zip'
#
# subset4.zip         100%[===================>]   6.38G  13.1MB/s    in 7m 20s
#
# 2024-11-03 09:40:26 (14.8 MB/s) - 'subset4.zip' saved [6856144330/6856144330]

# %%
# !unzip -q /kaggle/working/subset4.zip -d /kaggle/working/

# %%
# !rm subset4.zip

# %%
import SimpleITK as sitk
import numpy as np
import csv
from glob import glob
import pandas as pd
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import cv2

# %%
# LUNA_mask_extraction.py
subset = "subset4"
file_list = os.listdir(f"/kaggle/working//{subset}")
file_list = list(map(lambda file : f"/kaggle/working/{subset}/" + file, file_list))

# %%
def myFunc(file):
  if file.endswith(".mhd"):
    return True
  else:
    return False

file_list = list(filter(myFunc, file_list))

# %%
# !mkdir ct_images

# %%
def make_mask(center, diam, z, width, height, spacing, origin):
    '''
        Center : centers of circles px -- list of coordinates x,y,z
        diam : diameters of circles px -- diameter
        widthXheight : pixel dim of image
        spacing = mm/px conversion rate np array x,y,z
        origin = x,y,z mm np.array
        z = z position of slice in world coordinates mm
    '''
    mask = np.zeros([height, width]) # 0's everywhere except nodule swapping x,y to match img
    #convert to nodule space from world coordinates

    # Defining the voxel range in which the nodule falls
    v_center = (center - origin)/spacing
    v_diam = int(diam/spacing[0] + 1)
    v_xmin = np.max([0, int(v_center[0]-v_diam/2) - 2])
    v_xmax = np.min([width-1, int(v_center[0]+v_diam/2) + 2])
    v_ymin = np.max([0, int(v_center[1]-v_diam/2) - 2]) 
    v_ymax = np.min([height-1, int(v_center[1]+v_diam/2) + 2])

    v_xrange = range(v_xmin, v_xmax+1)
    v_yrange = range(v_ymin, v_ymax+1)

    # Fill in 1 within sphere around nodule
    for v_x in v_xrange:
        for v_y in v_yrange:
            p_x = spacing[0]*v_x + origin[0]
            p_y = spacing[1]*v_y + origin[1]
            if np.linalg.norm(center - np.array([p_x, p_y, z])) <= diam:
                mask[int((p_y-origin[1]) / spacing[1]), int((p_x-origin[0]) / spacing[0])] = 1.0
    return(mask, [v_xmin, v_xmax, v_ymin, v_ymax])

def get_filename(case):
    global file_list
    for f in file_list:
        if case in f:
            return(f)
        
def normalize(image):
    MIN_BOUND = -1000.0
    MAX_BOUND = 400.0
    image = (image - MIN_BOUND) / (MAX_BOUND - MIN_BOUND)
    image[image>1] = 1.
    image[image<0] = 0.
    return image

# %%
if __name__ == "__main__":
    df_node = pd.read_csv("/kaggle/working/annotations.csv")
    df_node["file"] = df_node["seriesuid"].apply(get_filename)
    df_node = df_node.dropna()
    # Define the file name
    file_name = 'output.csv'

    # Define the column names
    columns = ['x_min', 'x_max', 'y_min', 'y_max', 'ID']

    # Create an empty CSV file with column headers
    with open(file_name, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=columns)
        writer.writeheader()
    df_roi = pd.read_csv("output.csv")
    df_roi_cur = dict()
    
    print(f"TRÍCH XUẤT ẢNH VÀ TỌA ĐỘ TỪ FILE .raw VÀ FILE .mhd TỪ {subset}")
    for fcount, img_file in enumerate(tqdm(file_list)):
        mini_df = df_node[df_node["file"]==img_file] # get all nodules associate with file
        if len(mini_df) > 0:       # some files may not have a nodule--skipping those
            itk_img = sitk.ReadImage(img_file) # read .mhd file
            img_array = sitk.GetArrayFromImage(itk_img) # indexes are z,y,x (notice the ordering)
            num_z, height, width = img_array.shape
            origin = np.array(itk_img.GetOrigin())      # x,y,z  Origin in world coordinates (mm)
            spacing = np.array(itk_img.GetSpacing())    # spacing of voxels in world coor. (mm)
            
            for node_idx, cur_row in mini_df.iterrows():       
                node_x = cur_row["coordX"]
                node_y = cur_row["coordY"]
                node_z = cur_row["coordZ"]
                diam = cur_row["diameter_mm"]
                
                # imgs = np.ndarray([num_z, height, width], dtype=np.float16)
                center = np.array([node_x, node_y, node_z])   # nodule center
                v_center = np.rint((center-origin)/spacing)  # nodule center in voxel space (still x,y,z ordering)
            
                for i_z in range(0, num_z): # clip prevents going out of bounds in Z
                    _, roi = make_mask(center, diam, i_z*spacing[2]+origin[2], width, height, spacing, origin)
                    if i_z == v_center[2]:
                        roi_key = f"{img_file.split('/')[-1].rsplit('.', 1)[0]}_{i_z}_{node_idx}"
                        img_name = f"{img_file.split('/')[-1].rsplit('.', 1)[0]}_{i_z}_{node_idx}.png"
                        img = normalize(img_array[i_z])
                        img = img * 255
                        img_rgb = np.stack((img,)*3, -1)
                        cv2.imwrite(f"/kaggle/working/ct_images/{img_name}", img_rgb)
                        df_roi_cur.update({roi_key: roi})
                    # imgs[i_z] = img_array[i_z]
    df_temp = pd.DataFrame.from_dict(df_roi_cur, columns=["x_min", "x_max", "y_min", "y_max"], orient='index')
    df_temp["ID"] = list(df_roi_cur.keys())
    df_temp = df_temp.reset_index(drop=True)
    df_roi = pd.concat([df_roi, df_temp])
    df_roi.to_csv("output.csv", index=False)
# Out:
# TRÍCH XUẤT ẢNH VÀ TỌA ĐỘ TỪ FILE .raw VÀ FILE .mhd TỪ subset4
# 100%|██████████| 89/89 [01:18<00:00,  1.14it/s]

# %%
# !zip -r subset4.zip /kaggle/working/ct_images /kaggle/working/output.csv
# Out:
#   adding: kaggle/working/ct_images/ (stored 0%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972_42_80.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.189483585244687808087477024767_39_354.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.211956804948320236390242845468_275_449.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750_83_1111.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.173101104804533997398137418032_213_268.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265775376735520890308424143898_188_680.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.141430002307216644912805017227_89_153.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.177252583002664900748714851615_190_301.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.214800939017429618305208626314_110_466.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.320111824803959660037459294083_60_885.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.897684031374557757145405000951_135_1132.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.463214953282361219537913355115_40_993.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306_81_18.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.205993750485568250373835565680_238_432.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.304700823314998198591652152637_54_837.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.218476624578721885561483687176_107_488.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.244590453955380448651329424024_200_595.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.161855583909753609742728521805_36_222.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.780558315515979171413904604168_164_1098.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.198698492013538481395497694975_94_390.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.228511122591230092662900221600_114_538.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.161855583909753609742728521805_80_220.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.214800939017429618305208626314_61_462.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.337845202462615014431060697507_109_943.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950_56_1147.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.276710697414087561012670296643_112_731.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.307835307280028057486413359377_79_843.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.214800939017429618305208626314_91_464.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.114195693932194925962391697338_133_47.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972_38_79.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.214800939017429618305208626314_55_461.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.230416590143922549745658357505_145_550.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950_85_1150.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.228511122591230092662900221600_129_539.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306_126_22.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750_54_1112.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.161855583909753609742728521805_102_218.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.141511313712034597336182402384_409_157.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.142154819868944114554521645782_375_158.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.185226274332527104841463955058_79_328.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.287560874054243719452635194040_75_761.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.259123825760999546551970425757_197_658.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.897684031374557757145405000951_114_1134.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.205993750485568250373835565680_253_434.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.390513733720659266816639651938_209_963.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.242761658169703141430370511586_32_585.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306_96_19.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.211956804948320236390242845468_248_448.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.148229375703208214308676934766_142_172.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.270215889102603268207599305185_281_698.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750_37_1115.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.216252660192313507027754194207_111_475.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306_114_20.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950_46_1146.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.173101104804533997398137418032_268_270.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.228511122591230092662900221600_139_540.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.189483585244687808087477024767_73_355.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.584871944187559733312703328980_177_1033.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.216252660192313507027754194207_137_476.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.141430002307216644912805017227_108_154.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.268992195564407418480563388746_59_693.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.259123825760999546551970425757_152_661.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.259123825760999546551970425757_210_657.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306_110_17.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.204802250386343794613980417281_202_429.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306_117_21.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.214800939017429618305208626314_95_465.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.312704771348460502013249647868_109_867.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.164988920331211858091402361989_266_230.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.741709061958490690246385302477_99_1079.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.178680586845223339579041794709_42_305.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.779493719385047675154892222907_95_1097.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.214800939017429618305208626314_76_463.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.211051626197585058967163339846_104_447.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.300146276266881736689307479986_93_823.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.141430002307216644912805017227_84_152.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.205993750485568250373835565680_251_433.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.438308540025607517017949816111_69_982.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.300146276266881736689307479986_132_824.png (deflated 22%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750_48_1113.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950_87_1151.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.115386642382564804180764325545_187_56.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.897684031374557757145405000951_141_1136.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972_37_78.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.312704771348460502013249647868_177_865.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.248357157975955379661896491341_53_608.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.173101104804533997398137418032_223_269.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.259123825760999546551970425757_156_659.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.897684031374557757145405000951_117_1135.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.161855583909753609742728521805_91_219.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.741709061958490690246385302477_87_1080.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.419601611032172899567156073142_121_977.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950_62_1148.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.670107649586205629860363487713_109_1061.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.202643836890896697853521610450_106_419.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.161855583909753609742728521805_43_221.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.141511313712034597336182402384_298_156.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.148229375703208214308676934766_357_173.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.797637294244261543517154417124_67_1101.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.185226274332527104841463955058_113_329.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265775376735520890308424143898_164_682.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.218476624578721885561483687176_135_489.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.146987333806092287055399155268_49_167.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.897684031374557757145405000951_138_1133.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.198698492013538481395497694975_73_391.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.259123825760999546551970425757_64_660.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.401389720232123950202941034290_111_969.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.631047517458234322522264161877_129_1053.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750_107_1110.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750_44_1114.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.211956804948320236390242845468_282_450.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265775376735520890308424143898_196_681.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950_83_1149.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265960756233787099041040311282_407_684.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.910435939545691201820711078950_25_1145.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.312704771348460502013249647868_146_866.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.252358625003143649770119512644_234_632.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.779493719385047675154892222907_79_1096.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.119806527488108718706404165837_180_69.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.799582546798528864710752164515_246_1102.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.141511313712034597336182402384_379_155.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.438308540025607517017949816111_79_981.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972_48_82.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.198698492013538481395497694975_106_389.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.339546614783708685476232944897_80_955.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.230416590143922549745658357505_283_551.png (deflated 22%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972_34_77.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972_40_81.png (deflated 19%)
#   adding: kaggle/working/output.csv (deflated 74%)
