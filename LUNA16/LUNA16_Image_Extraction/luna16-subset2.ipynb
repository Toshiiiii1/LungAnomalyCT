# %%
# !wget https://zenodo.org/records/3723295/files/subset2.zip
# Out:
# --2024-11-03 08:39:35--  https://zenodo.org/records/3723295/files/subset2.zip
# Resolving zenodo.org (zenodo.org)... 188.185.79.172, 188.184.103.159, 188.184.98.238, ...
# Connecting to zenodo.org (zenodo.org)|188.185.79.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7257937108 (6.8G) [application/octet-stream]
# Saving to: 'subset2.zip'
#
# subset2.zip         100%[===================>]   6.76G  24.4MB/s    in 4m 8s
#
# 2024-11-03 08:43:44 (27.9 MB/s) - 'subset2.zip' saved [7257937108/7257937108]

# %%
# !wget https://zenodo.org/records/3723295/files/annotations.csv
# Out:
# --2024-11-03 08:43:45--  https://zenodo.org/records/3723295/files/annotations.csv
# Resolving zenodo.org (zenodo.org)... 188.184.98.238, 188.184.103.159, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136986 (134K) [text/plain]
# Saving to: 'annotations.csv'
#
# annotations.csv     100%[===================>] 133.78K   385KB/s    in 0.3s
#
# 2024-11-03 08:43:46 (385 KB/s) - 'annotations.csv' saved [136986/136986]

# %%
# !unzip -q /kaggle/working/subset2.zip -d /kaggle/working/

# %%
# !rm subset2.zip
# Out:
# rm: cannot remove 'subset2.zip': No such file or directory

# %%
import SimpleITK as sitk
import numpy as np
import csv
from glob import glob
import pandas as pd
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import cv2

# %%
# LUNA_mask_extraction.py
subset = "subset2"
file_list = os.listdir(f"/kaggle/working//{subset}")
file_list = list(map(lambda file : f"/kaggle/working/{subset}/" + file, file_list))

# %%
def myFunc(file):
  if file.endswith(".mhd"):
    return True
  else:
    return False

file_list = list(filter(myFunc, file_list))

# %%
# !mkdir ct_images

# %%
def make_mask(center, diam, z, width, height, spacing, origin):
    '''
        Center : centers of circles px -- list of coordinates x,y,z
        diam : diameters of circles px -- diameter
        widthXheight : pixel dim of image
        spacing = mm/px conversion rate np array x,y,z
        origin = x,y,z mm np.array
        z = z position of slice in world coordinates mm
    '''
    mask = np.zeros([height, width]) # 0's everywhere except nodule swapping x,y to match img
    #convert to nodule space from world coordinates

    # Defining the voxel range in which the nodule falls
    v_center = (center - origin)/spacing
    v_diam = int(diam/spacing[0] + 1)
    v_xmin = np.max([0, int(v_center[0]-v_diam/2) - 2])
    v_xmax = np.min([width-1, int(v_center[0]+v_diam/2) + 2])
    v_ymin = np.max([0, int(v_center[1]-v_diam/2) - 2]) 
    v_ymax = np.min([height-1, int(v_center[1]+v_diam/2) + 2])

    v_xrange = range(v_xmin, v_xmax+1)
    v_yrange = range(v_ymin, v_ymax+1)

    # Fill in 1 within sphere around nodule
    for v_x in v_xrange:
        for v_y in v_yrange:
            p_x = spacing[0]*v_x + origin[0]
            p_y = spacing[1]*v_y + origin[1]
            if np.linalg.norm(center - np.array([p_x, p_y, z])) <= diam:
                mask[int((p_y-origin[1]) / spacing[1]), int((p_x-origin[0]) / spacing[0])] = 1.0
    return(mask, [v_xmin, v_xmax, v_ymin, v_ymax])

def get_filename(case):
    global file_list
    for f in file_list:
        if case in f:
            return(f)
        
def normalize(image):
    MIN_BOUND = -1000.0
    MAX_BOUND = 400.0
    image = (image - MIN_BOUND) / (MAX_BOUND - MIN_BOUND)
    image[image>1] = 1.
    image[image<0] = 0.
    return image

# %%
if __name__ == "__main__":
    df_node = pd.read_csv("/kaggle/working/annotations.csv")
    df_node["file"] = df_node["seriesuid"].apply(get_filename)
    df_node = df_node.dropna()
    # Define the file name
    file_name = 'output.csv'

    # Define the column names
    columns = ['x_min', 'x_max', 'y_min', 'y_max', 'ID']

    # Create an empty CSV file with column headers
    with open(file_name, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=columns)
        writer.writeheader()
    df_roi = pd.read_csv("output.csv")
    df_roi_cur = dict()
    
    print(f"TRÍCH XUẤT ẢNH VÀ TỌA ĐỘ TỪ FILE .raw VÀ FILE .mhd TỪ {subset}")
    for fcount, img_file in enumerate(tqdm(file_list)):
        mini_df = df_node[df_node["file"]==img_file] # get all nodules associate with file
        if len(mini_df) > 0:       # some files may not have a nodule--skipping those
            itk_img = sitk.ReadImage(img_file) # read .mhd file
            img_array = sitk.GetArrayFromImage(itk_img) # indexes are z,y,x (notice the ordering)
            num_z, height, width = img_array.shape
            origin = np.array(itk_img.GetOrigin())      # x,y,z  Origin in world coordinates (mm)
            spacing = np.array(itk_img.GetSpacing())    # spacing of voxels in world coor. (mm)
            
            for node_idx, cur_row in mini_df.iterrows():       
                node_x = cur_row["coordX"]
                node_y = cur_row["coordY"]
                node_z = cur_row["coordZ"]
                diam = cur_row["diameter_mm"]
                
                # imgs = np.ndarray([num_z, height, width], dtype=np.float16)
                center = np.array([node_x, node_y, node_z])   # nodule center
                v_center = np.rint((center-origin)/spacing)  # nodule center in voxel space (still x,y,z ordering)
            
                for i_z in range(0, num_z): # clip prevents going out of bounds in Z
                    _, roi = make_mask(center, diam, i_z*spacing[2]+origin[2], width, height, spacing, origin)
                    if i_z == v_center[2]:
                        roi_key = f"{img_file.split('/')[-1].rsplit('.', 1)[0]}_{i_z}_{node_idx}"
                        img_name = f"{img_file.split('/')[-1].rsplit('.', 1)[0]}_{i_z}_{node_idx}.png"
                        img = normalize(img_array[i_z])
                        img = img * 255
                        img_rgb = np.stack((img,)*3, -1)
                        cv2.imwrite(f"/kaggle/working/ct_images/{img_name}", img_rgb)
                        df_roi_cur.update({roi_key: roi})
                    # imgs[i_z] = img_array[i_z]
    df_temp = pd.DataFrame.from_dict(df_roi_cur, columns=["x_min", "x_max", "y_min", "y_max"], orient='index')
    df_temp["ID"] = list(df_roi_cur.keys())
    df_temp = df_temp.reset_index(drop=True)
    df_roi = pd.concat([df_roi, df_temp])
    df_roi.to_csv("output.csv", index=False)
# Out:
# TRÍCH XUẤT ẢNH VÀ TỌA ĐỘ TỪ FILE .raw VÀ FILE .mhd TỪ subset2
# 100%|██████████| 89/89 [02:33<00:00,  1.72s/it]

# %%
# !zip -r subset2.zip /kaggle/working/ct_images /kaggle/working/output.csv
# Out:
#   adding: kaggle/working/ct_images/ (stored 0%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.121993590721161347818774929286_48_74.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.624425075947752229712087113746_53_1050.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478_97_744.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.227885601428639043345478571594_305_535.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265453131727473342790950829556_234_679.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405_252_4.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.267519732763035023633235877753_145_686.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187966156856911682643615997798_160_340.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.153536305742006952753134773630_96_192.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.147250707071097813243473865421_416_169.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.212346425055214308006918165305_53_451.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.144883090372691745980459537053_140_165.png (deflated 12%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.227796349777753378641347819780_183_534.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.133378195429627807109985347209_40_123.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.299767339686526858593516834230_52_814.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.226383054119800793308721198594_144_527.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.217955041973656886482758642958_106_487.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478_104_739.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405_230_5.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.252634638822000832774167856951_162_633.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187966156856911682643615997798_92_339.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.217697417596902141600884006982_200_483.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405_142_6.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.153536305742006952753134773630_108_193.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.126704785377921920210612476953_112_101.png (deflated 14%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.192256506776434538421891524301_77_358.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.124663713663969377020085460568_89_87.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187108608022306504546286626125_119_334.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.267519732763035023633235877753_136_685.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478_176_743.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.939152384493874708850321969356_68_1159.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.232071262560365924176679652948_150_558.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.302557165094691896097534021075_166_835.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.557875302364105947813979213632_304_1026.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.199171741859530285887752432478_140_392.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.144883090372691745980459537053_50_164.png (deflated 12%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.124663713663969377020085460568_113_88.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.153536305742006952753134773630_129_194.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.124663713663969377020085460568_113_89.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.147250707071097813243473865421_293_168.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.199975006921901879512837687266_215_400.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.192256506776434538421891524301_125_360.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.267957701183569638795986183786_176_691.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.443400977949406454649939526179_125_986.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265453131727473342790950829556_219_678.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265453131727473342790950829556_180_676.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187108608022306504546286626125_150_333.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.299767339686526858593516834230_45_813.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.184412674007117333405073397832_120_325.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.267957701183569638795986183786_204_689.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.557875302364105947813979213632_214_1025.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187966156856911682643615997798_316_338.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478_255_742.png (deflated 22%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877_204_1174.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.270152671889301412052226973069_55_697.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.142485715518010940961688015191_95_159.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.267519732763035023633235877753_352_687.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.299767339686526858593516834230_71_812.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.192256506776434538421891524301_113_359.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.253322967203074795232627653819_384_637.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877_202_1175.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.299767339686526858593516834230_82_811.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.199220738144407033276946096708_147_394.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.227796349777753378641347819780_310_532.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.692598144815688523679745963696_118_1067.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877_200_1173.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.133378195429627807109985347209_136_124.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.240969450540588211676803094518_56_577.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.692598144815688523679745963696_50_1068.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478_84_738.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.137375498893536422914241295628_89_134.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.143412474064515942785157561636_170_162.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478_163_740.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.163901773171373940247829492387_87_228.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.283569726884265181140892667131_42_753.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.280072876841890439628529365478_215_741.png (deflated 21%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.142485715518010940961688015191_194_161.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.199975006921901879512837687266_198_399.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.253322967203074795232627653819_165_639.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265453131727473342790950829556_161_675.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405_266_3.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.183924380327950237519832859527_83_323.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.153536305742006952753134773630_74_190.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.225154811831720426832024114593_80_519.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.217697417596902141600884006982_142_484.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.922852847124879997825997808179_289_1153.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.283569726884265181140892667131_20_755.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.190298296009658115773239776160_74_356.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.557875302364105947813979213632_163_1024.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.964952370561266624992539111877_194_1172.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.283569726884265181140892667131_49_752.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.461155505515403114280165935891_113_992.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.283569726884265181140892667131_38_754.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.922852847124879997825997808179_339_1154.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.217589936421986638139451480826_52_479.png (deflated 13%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.153536305742006952753134773630_81_191.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.299767339686526858593516834230_63_815.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.217589936421986638139451480826_217_482.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.443400977949406454649939526179_165_985.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311_172_1160.png (deflated 12%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.121993590721161347818774929286_58_75.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.192256506776434538421891524301_156_361.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.192256506776434538421891524301_157_362.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.159996104466052855396410079250_163_212.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187108608022306504546286626125_156_332.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.259227883564429312164962953756_163_663.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.267957701183569638795986183786_317_688.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.265453131727473342790950829556_199_677.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.283733738239331719775105586296_137_756.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.253322967203074795232627653819_275_638.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.217697417596902141600884006982_230_485.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.240969450540588211676803094518_90_578.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.217589936421986638139451480826_106_481.png (deflated 15%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.227796349777753378641347819780_203_533.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.225154811831720426832024114593_71_517.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.466284753932369813717081722101_189_994.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.199171741859530285887752432478_138_393.png (deflated 20%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.323753921818102744511069914832_51_895.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.142485715518010940961688015191_195_160.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187108608022306504546286626125_207_331.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.183924380327950237519832859527_56_322.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187108608022306504546286626125_215_330.png (deflated 19%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.187966156856911682643615997798_316_341.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.323753921818102744511069914832_72_896.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.225154811831720426832024114593_53_518.png (deflated 16%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.235364978775280910367690540811_71_564.png (deflated 17%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.267957701183569638795986183786_212_690.png (deflated 18%)
#   adding: kaggle/working/ct_images/1.3.6.1.4.1.14519.5.2.1.6279.6001.217589936421986638139451480826_53_480.png (deflated 13%)
#   adding: kaggle/working/output.csv (deflated 75%)
